# %% [markdown]
# <a href="https://colab.research.google.com/github/DanilChernov2006/work-space/blob/main/works.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

url = "https://drive.google.com/uc?export=download&id=1zXIy8T1KICuXtcbzYCqAtXbYX-2ta2Mu"
Data = pd.read_csv(url,header=None)
Data.head(1000)

axes = Data.plot(marker='.', figsize=(10,10), subplots = True)
axes = plt.grid()

Data_matrix = Data.values
