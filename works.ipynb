# %% [markdown]
# <a href="https://colab.research.google.com/github/DanilChernov2006/work-space/blob/works-update/works.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2

# %%
import numpy as np
import pandas as pd
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
output_notebook()

url = "https://drive.google.com/uc?export=download&id=1zXIy8T1KICuXtcbzYCqAtXbYX-2ta2Mu"
Data = pd.read_csv(url,header=None)
Data.head(1000)
Data_matrix=Data.values

Data_array = np.linspace(1,1000,1000)
Light_array = np.linspace(1,1000,1000)
for k in range(1000):
  i = Data_matrix[k]
  i = i.item()
  Data_array[k] = i
  if Data_array[k]<35:
    Light_array[k] = 1
  else:
    Light_array[k] = 0

p1 = figure()
p1.line(np.arange(len(Data_matrix)), Data_array, color="blue", line_width = 2)
p2 = figure()
p2.line(np.arange(len(Data_matrix)), Light_array, color="green", line_width = 2)
show(gridplot([p1, p2], ncols=1, width=800, height=400))
# Out:
#   <div id="b3b6679b-7197-4790-9f74-47c0933ad112" data-root-id="p3895" style="display: contents;"></div>
